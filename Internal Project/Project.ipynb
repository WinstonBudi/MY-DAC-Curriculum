# %% [markdown]
# # Internal Project Group 6

# %%
# !pip3 install pandas

# %%
import pandas as pd         # data manipulation & analysis
import numpy as np          # numerical & mathematical operations
import matplotlib.pyplot as plt         # for creating visualisations
import seaborn as  sns          # for more advanced visualisations

# %%
df = pd.read_csv('/Users/winstonbudihartono/Desktop/MY-DAC-Curriculum/Internal Project/Healthcare.csv')

# %% [markdown]
# ### Data contents and general information

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
print(df['Medical Condition'].unique())
# Out:
# ['Cancer' 'Obesity' 'Diabetes' 'Asthma' 'Hypertension' 'Arthritis']

# %%
print(df['Test Results'].unique())
# Out:
# ['Normal' 'Inconclusive' 'Abnormal']

# %%
tr_counts = df['Hospital'].value_counts()
print(tr_counts)
# Out:
# Hospital
# LLC Smith                      44
# Ltd Smith                      39
# Johnson PLC                    38
# Smith Ltd                      37
# Smith PLC                      36
#                                ..
# and Montoya Flores, Boyer       1
# Carter and Dunn King,           1
# Hall, Brown Black and           1
# Peterson Scott and Thomas,      1
# Moreno Murphy, Griffith and     1
# Name: count, Length: 39876, dtype: int64

# %%
mc_counts = df['Medical Condition'].value_counts()
print(mc_counts)
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %% [markdown]
# ### Checking for null values

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# ### Checking for duplicated values

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (534, 15)

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Cleaned data

# %%
df = pd.read_csv('/Users/winstonbudihartono/Desktop/MY-DAC-Curriculum/Internal Project/cleaned_file.csv')

# %% [markdown]
# ### Imrpove the accuracy of test results (Medical Conditions VS Test Results)

# %%
df['Test Results'].value_counts().plot(kind='bar', title='Medical Conditions vs. Test Results', color='Red')
plt.xticks(rotation=0) 
plt.show()

# %%
df['Medical Condition'].value_counts().plot(kind='bar', title='Medical Conditions vs. Test Results', color='Blue')
plt.xticks(rotation=0) 
plt.show()

# %% [markdown]
# ### ML

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn import tree

# %%
label_encoder = LabelEncoder()

# Apply Label Encoding to all object type columns in the dataset
for column in df.select_dtypes(include=['object']).columns:
    df[column] = label_encoder.fit_transform(df[column])

# Compute the correlation matrix
correlation_matrix = df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                         Name       Age    Gender  Blood Type  \
# Name                1.000000  0.001151  0.007992   -0.001075
# Age                 0.001151  1.000000 -0.002510   -0.000031
# Gender              0.007992 -0.002510  1.000000   -0.000690
# Blood Type         -0.001075 -0.000031 -0.000690    1.000000
# Medical Condition   0.003250 -0.002800  0.000746   -0.004183
# Date of Admission   0.003662 -0.000877  0.001649   -0.000147
# Doctor             -0.005099 -0.003225 -0.002916   -0.004764
# Hospital            0.003629  0.001728  0.003262   -0.000457
# Insurance Provider -0.001197 -0.005222 -0.003267   -0.001097
# Billing Amount     -0.001584 -0.003427  0.004939   -0.000575
# Room Number        -0.001004 -0.000352 -0.006764    0.004465
# Admission Type      0.004086  0.004098  0.009642   -0.004305
# Discharge Date      0.003678 -0.000748  0.001718   -0.000175
# Medication          0.000286 -0.006073  0.007855    0.002778
# ...

# %%
corr_matrix = df.corr(numeric_only=True)
fig,ax = plt.subplots(figsize=(17,7))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
#  1. Weak correlations across most variables
#  - Indicate that each factor (age, gender, medical condition, etc.) may influence the outcome (e.g., billing amount, discharge date) independently rather than in a connected way.
#  2. Correlation between Doctor VS Medical Condition
#  - The correlation is 0.0079, indicating a very weak positive relationship. Suggests that different doctors may treat a specific set of conditions, but the relationship is not strong enough to be a deciding factor in a predictive model. It could be valuable to explore this further, especially in a larger dataset.
#  3. Insurance Provider VS Billing Amount
#  - The correlation is -0.0039, which is very weak. Suggests that the insurance provider has little to no impact on the total billing amount. Tbilling amount is likely determined by other factors (e.g., medical condition, room number, etc.) rather than the insurance provider.
#  4. Hospital VS Billing Amount
#  - A slight positive correlation of 0.0031. Suggests that the hospital type or its facilities could have some influence on the total billing amount. More expensive hospitals might result in higher bills, but the correlation is not strong enough to draw definitive conclusions.
#  5. Room Number VS Billing Amount
#  - A 0.0079 correlation, which suggests a weak but positive relationship. Indicates that certain types of rooms (e.g., private vs. shared rooms) might correlate with higher or lower billing amounts. More expensive rooms could result in higher charges, though the relationship is weak.
#  6. Admission Type VS Discharge Date
#  - A 0.0072 positive correlation. Suggests that the type of admission could slightly influence how long a patient stays in the hospital, though the correlation is not strong enough to be a key driver of length of stay.
#  7. Medication and Test Results
#  - The correlation is 0.0025, which is extremely weak. Suggests there is little to no relationship between whether medication was administered and the results of tests, which could indicate that the treatment given does not directly influence the tests' outcomes.
#  8. Discharge Date and Test Results
#  - A very weak negative correlation of -0.0001. Suggests that there’s almost no relationship between when a patient is discharged and the results of their medical tests.
#  9. No strong relationships for key outcomes
#  - No strong correlations in the matrix. Suggests that none of the variables strongly predict the outcomes. It may be worth considering using non-linear models or adding interaction terms to capture more complex relationships between these features in predictive modeling.
# General Insight:
# The heatmap shows that this dataset may be relatively independent in its variables, meaning simple linear models may not work very effectively for prediction. Advanced models, like decision trees or neural networks, may perform better in this context by capturing more intricate relationships between the features.
